# %% [markdown]
# <a href="https://colab.research.google.com/github/pabloisaiahs/DS-3001-Project-1/blob/main/clean_and_tokenize_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install and download SpaCy model if not already installed
# !pip install spacy
# !python -m spacy download en_core_web_sm

# %%
import pandas as pd
import spacy
import re

# Load SpaCy's English model
nlp = spacy.load("en_core_web_sm")

# Load the dataset
file_path = "truncated_data.csv"  # Update path if necessary
df = pd.read_csv(file_path)

# Display column names to confirm structure
print(df.columns)

# Use the correct column name for reviews
column_name = 'review'  # Update based on actual dataset

# Drop missing values in review column
df = df.dropna(subset=[column_name])

# Text Cleaning Function
def clean_text(text):
    text = str(text).lower()  # Convert to lowercase
    text = re.sub(r'[^a-z\s]', '', text)  # Remove special characters and numbers
    return text

df['cleaned_text'] = df[column_name].apply(clean_text)

# Tokenization using SpaCy
df['tokens'] = df['cleaned_text'].apply(lambda text: [token.text for token in nlp(text)])

# Save cleaned data
df.to_csv("truncated_data_cleaned.csv", index=False)

print("Cleaning and tokenization complete. File saved as 'steam_reviews_cleaned.csv'.")
# Out:
# Index(['X', 'app_id', 'app_name', 'review_id', 'language', 'review',
#        'timestamp_created', 'timestamp_updated', 'recommended',
#        'votes_helpful', 'votes_funny', 'weighted_vote_score', 'comment_count',
#        'steam_purchase', 'received_for_free', 'written_during_early_access',
#        'author.steamid', 'author.num_games_owned', 'author.num_reviews',
#        'author.playtime_forever', 'author.playtime_last_two_weeks',
#        'author.playtime_at_review', 'author.last_played'],
#       dtype='object')
# Cleaning and tokenization complete. File saved as 'steam_reviews_cleaned.csv'.

# %%
df.head(10)
# Out:
#          X  app_id                                      app_name  review_id  \
# 0  1708660    8930                    Sid Meier's Civilization V   10119388
# 1  1616223    8930                    Sid Meier's Civilization V   41348992
# 2  1699760    8930                    Sid Meier's Civilization V   11281803
# 3  4437439  227300                        Euro Truck Simulator 2   20641037
# 4  3294571  275390  Guacamelee! Super Turbo Championship Edition   46022055
# 5  5716437  413150                                Stardew Valley   53227635
# 6  1877269  381210                              Dead by Daylight   65059694
# 7  2916537  242760                                    The Forest   46729731
# 8  5570322  413150                                Stardew Valley   82524476
# 9  4673448  431960                              Wallpaper Engine   58659053
#
#   language                                             review  \
# 0  english  Great Game if you like Strategy Games. I would...
# 1  english  Much inferior version of CIV 4. The only posit...
# 2  english       Do you like losing time? Do you like miss...
# 3  english                                                (y)
# 4  english                                                bom
# 5  english       Good game! Farm and do other stuff. Love it!
# 6  english                        its great. need i say more.
# 7  english                                 I died at caves...
# 8  english                vloe gaems so goodp woud recomencad
# 9  english                                This app is amazing
#
#    timestamp_created  timestamp_updated  recommended  votes_helpful  ...  \
# 0         1400168834         1400168834         True              0  ...
# 1         1523134094         1523134094        False              0  ...
# 2         1405564142         1405564142         True              1  ...
# 3         1453293826         1453293826         True              0  ...
# 4         1542833752         1542833752         True              0  ...
# 5         1562098071         1562098071         True              0  ...
# 6         1584237891         1584237891         True              0  ...
# 7         1543047361         1543047361         True              0  ...
# 8         1608157188         1608157188         True              0  ...
# 9         1575076707         1575076707         True              0  ...
#
#    written_during_early_access     author.steamid  author.num_games_owned  \
# 0                        False  76561198132502300                      14
# 1                        False  76561198012377800                     137
# 2                        False  76561198064377700                     231
# 3                        False  76561198182331700                      39
# 4                        False  76561198080521200                     132
# 5                        False  76561198081613800                     229
# 6                        False  76561198156042400                     199
# 7                        False  76561198113814200                     152
# 8                        False  76561198804048400                      67
# 9                        False  76561198009016800                    3606
#
#    author.num_reviews  author.playtime_forever  \
# 0                   1                     2135
# 1                  18                     3382
# 2                   4                    72192
# 3                   2                      325
# 4                   6                      863
# 5                   1                     2920
# 6                  23                     2310
# 7                  13                     3849
# 8                   5                     2664
# 9                  66                    16272
#
#    author.playtime_last_two_weeks  author.playtime_at_review  \
# 0                               0                      879.0
# 1                               0                     3382.0
# 2                               0                    15114.0
# 3                               0                      162.0
# 4                               0                      863.0
# 5                               0                     2504.0
# 6                               0                     1822.0
# 7                             368                     2249.0
# 8                               0                     2422.0
# 9                               0                    10278.0
#
#    author.last_played                                       cleaned_text  \
# 0          1416590688  great game if you like strategy games i would ...
# 1          1366354800  much inferior version of civ  the only positiv...
# 2          1609388410       do you like losing time do you like missi...
# 3          1582858855                                                  y
# 4          1524755224                                                bom
# 5          1609450155          good game farm and do other stuff love it
# 6          1589077795                          its great need i say more
# 7          1610470353                                    i died at caves
# 8          1608692186                vloe gaems so goodp woud recomencad
# 9          1607315645                                this app is amazing
#
#                                               tokens
# 0  [great, game, if, you, like, strategy, games, ...
# 1  [much, inferior, version, of, civ,  , the, onl...
# 2  [     , do, you, like, losing, time, do, you, ...
# 3                                                [y]
# 4                                              [bom]
# 5  [good, game, farm, and, do, other, stuff, love...
# 6                   [its, great, need, i, say, more]
# 7                               [i, died, at, caves]
# 8         [vloe, gaems, so, goodp, woud, recomencad]
# 9                           [this, app, is, amazing]
#
# [10 rows x 25 columns]
